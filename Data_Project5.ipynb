# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
import numpy as np
from functools import reduce
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from statsmodels.tsa.ar_model import AutoReg

# %%
oda_received=pd.read_excel("ODA Received.xls")
#oda_received["Country Name"].unique()

# %%
list_regions=['Fragile and conflict affected situations', 'Heavily indebted poor countries (HIPC)', 'Least developed countries: UN classification', 'Low income', 'Lower middle income']
condition=(oda_received["Country Name"]=='Fragile and conflict affected situations')|(oda_received["Country Name"]=='Heavily indebted poor countries (HIPC)')|(oda_received["Country Name"]=='Least developed countries: UN classification')|(oda_received["Country Name"]=='Low income')|(oda_received["Country Name"]=='Lower middle income')
oda_rec=oda_received[condition].copy()
oda_rec=oda_rec.drop("Country Code", axis=1)
#oda_rec

# %%
liability=pd.read_excel("Liability.xls")
condition=(liability["Country Name"]=='Fragile and conflict affected situations')|(liability["Country Name"]=='Heavily indebted poor countries (HIPC)')|(liability["Country Name"]=='Least developed countries: UN classification')|(liability["Country Name"]=='Low income')|(liability["Country Name"]=='Lower middle income')
liab=liability[condition].copy()
liab=liab.drop("Country Code", axis=1)
#liab

# %%
gdp=pd.read_excel("GDP per capita.xls")
condition_2=(gdp["Country Name"]=='Fragile and conflict affected situations')|(gdp["Country Name"]=='Heavily indebted poor countries (HIPC)')|(gdp["Country Name"]=='Least developed countries: UN classification')|(gdp["Country Name"]=='Low income')|(gdp["Country Name"]=='Lower middle income')
gdp_capita=gdp[condition_2].copy()
gdp_capita=gdp_capita.drop("Country Code", axis=1)
#gdp_capita

# %%
inv=pd.read_excel("FDI.xls")
condition_3=(inv["Country Name"]=='Fragile and conflict affected situations')|(inv["Country Name"]=='Heavily indebted poor countries (HIPC)')|(inv["Country Name"]=='Least developed countries: UN classification')|(inv["Country Name"]=='Low income')|(inv["Country Name"]=='Lower middle income')
fdi=inv[condition_3].copy()
fdi=fdi.drop("Country Code", axis=1)
#fdi

# %%
inf=pd.read_excel("Inflation.xls")
condition_4=(inf["Country Name"]=='Fragile and conflict affected situations')|(inf["Country Name"]=='Heavily indebted poor countries (HIPC)')|(inf["Country Name"]=='Least developed countries: UN classification')|(inf["Country Name"]=='Low income')|(inf["Country Name"]=='Lower middle income')
inflation=inf[condition_4].copy()
inflation=inflation.drop("Country Code", axis=1)
#inflation

# %%
oppenness=pd.read_excel("Trade.xls")
condition_5=(oppenness["Country Name"]=='Fragile and conflict affected situations')|(oppenness["Country Name"]=='Heavily indebted poor countries (HIPC)')|(oppenness["Country Name"]=='Least developed countries: UN classification')|(oppenness["Country Name"]=='Low income')|(oppenness["Country Name"]=='Lower middle income')
trade=oppenness[condition_5].copy()
trade=trade.drop("Country Code", axis=1)
#trade

# %%
life=pd.read_excel("Life Expectancy.xls")
condition_7=(life["Country Name"]=='Fragile and conflict affected situations')|(life["Country Name"]=='Heavily indebted poor countries (HIPC)')|(life["Country Name"]=='Least developed countries: UN classification')|(life["Country Name"]=='Low income')|(life["Country Name"]=='Lower middle income')
life_expectancy=life[condition_7].copy()
life_expectancy=life_expectancy.drop("Country Code", axis=1)
#life_expectancy

# %%
pop=pd.read_excel("Population.xls")
condition_8=(pop["Country Name"]=='Fragile and conflict affected situations')|(pop["Country Name"]=='Heavily indebted poor countries (HIPC)')|(pop["Country Name"]=='Least developed countries: UN classification')|(pop["Country Name"]=='Low income')|(pop["Country Name"]=='Lower middle income')
population=pop[condition_8].copy()
population=population.drop("Country Code", axis=1)
#population

# %%
debt=pd.read_excel("Debt.xls")
condition_9=(debt["Country Name"]=='Fragile and conflict affected situations')|(debt["Country Name"]=='Heavily indebted poor countries (HIPC)')|(debt["Country Name"]=='Least developed countries: UN classification')|(debt["Country Name"]=='Low income')|(debt["Country Name"]=='Lower middle income')
debt_policy=debt[condition_9].copy()
debt_policy=debt_policy.drop("Country Code", axis=1)
#debt_policy

# %%
labor=pd.read_excel("Labor Force.xls")
condition_10=(labor["Country Name"]=='Fragile and conflict affected situations')|(labor["Country Name"]=='Heavily indebted poor countries (HIPC)')|(labor["Country Name"]=='Least developed countries: UN classification')|(labor["Country Name"]=='Low income')|(labor["Country Name"]=='Lower middle income')
labor_force=labor[condition_10].copy()
labor_force=labor_force.drop("Country Code", axis=1)
#labor_force

# %%
oda_filter=pd.melt(oda_rec, id_vars=['Country Name'])
oda_filter["variable"] = oda_filter["variable"].astype(int)
oda_received_2010_2019=oda_filter[(oda_filter["variable"]>=2010)&(oda_filter["variable"]<=2019)]
oda_received_2010_2019.rename(columns={"value":"ODA Received"}, inplace=True)
oda_received_2010_2019.head(2)
# Out:
# /var/folders/j7/4yrzqvzn643dv0t5y434hfhw0000gn/T/ipykernel_16317/1333767658.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oda_received_2010_2019.rename(columns={"value":"ODA Received"}, inplace=True)
#                                  Country Name  variable  ODA Received
# 250  Fragile and conflict affected situations      2010  3.839381e+10
# 251    Heavily indebted poor countries (HIPC)      2010  4.396860e+10

# %%
liability_filter=pd.melt(liab, id_vars=['Country Name'])
liability_filter["variable"] = liability_filter["variable"].astype(int)
liability_received_2010_2019=liability_filter[(liability_filter["variable"]>=2010)&(liability_filter["variable"]<=2019)]
liability_received_2010_2019.rename(columns={"value":"Transparency_Accountability_Corruption_PublicSector_Rating"}, inplace=True)
liability_received_2010_2019.head(2)
# Out:
# /var/folders/j7/4yrzqvzn643dv0t5y434hfhw0000gn/T/ipykernel_16317/561382229.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liability_received_2010_2019.rename(columns={"value":"Transparency_Accountability_Corruption_PublicSector_Rating"}, inplace=True)
#                                  Country Name  variable  \
# 250  Fragile and conflict affected situations      2010
# 251    Heavily indebted poor countries (HIPC)      2010
#
#      Transparency_Accountability_Corruption_PublicSector_Rating
# 250                                           2.574074
# 251                                           2.657895

# %%
gdp_filter=pd.melt(gdp_capita, id_vars=['Country Name'])
gdp_filter["variable"] = gdp_filter["variable"].astype(int)
gdp_capita_2010_2019=gdp_filter[(gdp_filter["variable"]>=2010)&(gdp_filter["variable"]<=2019)]
gdp_capita_2010_2019.rename(columns={"value":"GDP per capita"}, inplace=True)
gdp_capita_2010_2019.head(2)
# Out:
# /var/folders/j7/4yrzqvzn643dv0t5y434hfhw0000gn/T/ipykernel_16317/1327985279.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_capita_2010_2019.rename(columns={"value":"GDP per capita"}, inplace=True)
#                                  Country Name  variable  GDP per capita
# 250  Fragile and conflict affected situations      2010     2296.709859
# 251    Heavily indebted poor countries (HIPC)      2010      808.891113

# %%
fdi_filter=pd.melt(fdi, id_vars=['Country Name'])
fdi_filter["variable"] = fdi_filter["variable"].astype(int)
fdi_2010_2019=fdi_filter[(fdi_filter["variable"]>=2010)&(fdi_filter["variable"]<=2019)]
fdi_2010_2019.rename(columns={"value":"FDI (%GDP)"}, inplace=True)
fdi_2010_2019.head(2)
# Out:
# /var/folders/j7/4yrzqvzn643dv0t5y434hfhw0000gn/T/ipykernel_16317/2513161150.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fdi_2010_2019.rename(columns={"value":"FDI (%GDP)"}, inplace=True)
#                                  Country Name  variable  FDI (%GDP)
# 250  Fragile and conflict affected situations      2010    1.976136
# 251    Heavily indebted poor countries (HIPC)      2010    4.701794

# %%
inflation_filter=pd.melt(inflation, id_vars=['Country Name'])
inflation_filter["variable"] = inflation_filter["variable"].astype(int)
inflation_2010_2019=inflation_filter[(inflation_filter["variable"]>=2010)&(inflation_filter["variable"]<=2019)]
inflation_2010_2019.rename(columns={"value":"Inflation"}, inplace=True)
inflation_2010_2019.head(2)
# Out:
# /var/folders/j7/4yrzqvzn643dv0t5y434hfhw0000gn/T/ipykernel_16317/4139895453.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inflation_2010_2019.rename(columns={"value":"Inflation"}, inplace=True)
#                                  Country Name  variable  Inflation
# 250  Fragile and conflict affected situations      2010   3.480508
# 251    Heavily indebted poor countries (HIPC)      2010   4.698891

# %%
trade_filter=pd.melt(trade, id_vars=['Country Name'])
trade_filter["variable"] = trade_filter["variable"].astype(int)
trade_2010_2019=trade_filter[(trade_filter["variable"]>=2010)&(trade_filter["variable"]<=2019)]
trade_2010_2019.rename(columns={"value":"Trade (%GDP)"}, inplace=True)
trade_2010_2019.head(2)
# Out:
# /var/folders/j7/4yrzqvzn643dv0t5y434hfhw0000gn/T/ipykernel_16317/3531069834.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_2010_2019.rename(columns={"value":"Trade (%GDP)"}, inplace=True)
#                                  Country Name  variable  Trade (%GDP)
# 250  Fragile and conflict affected situations      2010     56.316139
# 251    Heavily indebted poor countries (HIPC)      2010     63.986598

# %%
life_expectancy_filter=pd.melt(life_expectancy, id_vars=['Country Name'])
life_expectancy_filter["variable"] = life_expectancy_filter["variable"].astype(int)
life_expectancy_2010_2019=life_expectancy_filter[(life_expectancy_filter["variable"]>=2010)&(life_expectancy_filter["variable"]<=2019)]
life_expectancy_2010_2019.rename(columns={"value":"Life Expectancy (Years)"}, inplace=True)
life_expectancy_2010_2019.head(2)
# Out:
# /var/folders/j7/4yrzqvzn643dv0t5y434hfhw0000gn/T/ipykernel_16317/117189239.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   life_expectancy_2010_2019.rename(columns={"value":"Life Expectancy (Years)"}, inplace=True)
#                                  Country Name  variable  \
# 250  Fragile and conflict affected situations      2010
# 251    Heavily indebted poor countries (HIPC)      2010
#
#      Life Expectancy (Years)
# 250                59.120581
# 251                58.858947

# %%
population_filter=pd.melt(population, id_vars=['Country Name'])
population_filter["variable"] = population_filter["variable"].astype(int)
population_2010_2019=population_filter[(population_filter["variable"]>=2010)&(population_filter["variable"]<=2019)]
population_2010_2019.rename(columns={"value":"Population"}, inplace=True)
population_2010_2019.head(2)
# Out:
# /var/folders/j7/4yrzqvzn643dv0t5y434hfhw0000gn/T/ipykernel_16317/1645350862.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population_2010_2019.rename(columns={"value":"Population"}, inplace=True)
#                                  Country Name  variable   Population
# 250  Fragile and conflict affected situations      2010  735448194.0
# 251    Heavily indebted poor countries (HIPC)      2010  624219296.0

# %%
debt_policy_filter=pd.melt(debt_policy, id_vars=['Country Name'])
debt_policy_filter["variable"] = debt_policy_filter["variable"].astype(int)
debt_policy_2010_2019=debt_policy_filter[(debt_policy_filter["variable"]>=2010)&(debt_policy_filter["variable"]<=2019)]
debt_policy_2010_2019.rename(columns={"value":"Debt Policy Rating"}, inplace=True)
debt_policy_2010_2019.head(2)
# Out:
# /var/folders/j7/4yrzqvzn643dv0t5y434hfhw0000gn/T/ipykernel_16317/2307743404.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   debt_policy_2010_2019.rename(columns={"value":"Debt Policy Rating"}, inplace=True)
#                                  Country Name  variable  Debt Policy Rating
# 250  Fragile and conflict affected situations      2010            3.166667
# 251    Heavily indebted poor countries (HIPC)      2010            3.236842

# %%
labor_force_filter=pd.melt(labor_force, id_vars=['Country Name'])
labor_force_filter["variable"] = labor_force_filter["variable"].astype(int)
labor_force_2010_2019=labor_force_filter[(labor_force_filter["variable"]>=2010)&(labor_force_filter["variable"]<=2019)]
labor_force_2010_2019.rename(columns={"value":"Labor Force (%Population)"}, inplace=True)
labor_force_2010_2019.head(2)
# Out:
# /var/folders/j7/4yrzqvzn643dv0t5y434hfhw0000gn/T/ipykernel_16317/574819677.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labor_force_2010_2019.rename(columns={"value":"Labor Force (%Population)"}, inplace=True)
#                                  Country Name  variable  \
# 250  Fragile and conflict affected situations      2010
# 251    Heavily indebted poor countries (HIPC)      2010
#
#      Labor Force (%Population)
# 250                  64.843223
# 251                  71.819260

# %%
list_data=[oda_received_2010_2019, labor_force_2010_2019, debt_policy_2010_2019, population_2010_2019, life_expectancy_2010_2019,
           trade_2010_2019, inflation_2010_2019, fdi_2010_2019, gdp_capita_2010_2019, liability_received_2010_2019]

#gdp_capita_2010_2019.merge(, how='inner', on=['Country Name', "variable"])

df_merge = reduce(lambda left, right: pd.merge(left, right, on=['Country Name', "variable"], how="inner"), list_data)
df_merge.rename(columns={"variable":"Year"}, inplace=True)
df_merge.head()
#df_merge.to_csv("Full_Data")
# Out:
#                                    Country Name  Year  ODA Received  \
# 0      Fragile and conflict affected situations  2010  3.839381e+10
# 1        Heavily indebted poor countries (HIPC)  2010  4.396860e+10
# 2  Least developed countries: UN classification  2010  4.359978e+10
# 3                                    Low income  2010  3.318832e+10
# 4                           Lower middle income  2010  3.914048e+10
#
#    Labor Force (%Population)  Debt Policy Rating    Population  \
# 0                  64.843223            3.166667  7.354482e+08
# 1                  71.819260            3.236842  6.242193e+08
# 2                  69.540799            3.244186  8.366148e+08
# 3                  69.930830            3.108696  5.137833e+08
# 4                  60.406194            3.560976  2.878875e+09
#
#    Life Expectancy (Years)  Trade (%GDP)  Inflation  FDI (%GDP)  \
# 0                59.120581     56.316139   3.480508    1.976136
# 1                58.858947     63.986598   4.698891    4.701794
# 2                61.388934     59.462524   5.516113    2.738155
# 3                59.739740     59.760608   4.723547    2.652487
# 4                66.372159     55.583573   4.827342    1.889465
#
#    GDP per capita  Transparency_Accountability_Corruption_PublicSector_Rating
# 0     2296.709859                                           2.574074
# 1      808.891113                                           2.657895
# 2      805.306314                                           2.697674
# 3     1125.394877                                           2.543478
# 4     1806.542548                                           2.865854

# %%
##CHEAT SHEET: 

##P-value
#If 95% of the t distribution is closer to the mean than the t-value on the coefficient you are looking at, 
#then you have a P value of 5%. This is also reffered to a significance level of 5%. The P value is the 
#probability of seeing a result as extreme as the one you are getting (a t value as large as yours) in a 
#collection of random data in which the variable had no effect. A P of 5% or less is the generally 
#accepted point at which to reject the null hypothesis. With a P value of 5% (or .05) there is only a 5% 
#chance that results you are seeing would have come up in a random distribution, so you can say with a 95% 
#probability of being correct that the variable is having some effect, assuming your model is specified correctly.

#The 95% confidence interval for your coefficients shown by many regression packages gives you the same information. 
#You can be 95% confident that the real, underlying value of the coefficient that you are estimating falls somewhere 
#in that 95% confidence interval, so if the interval does not contain 0, your P value will be .05 or less.

#Note that the size of the P value for a coefficient says nothing about the size of the effect that variable 
#is having on your dependent variable - it is possible to have a highly significant result (very small P-value) 
#for a miniscule effect.

#In regression with multiple independent variables, the coefficient tells you how much the dependent variable 
#is expected to increase when that independent variable increases by one, holding all the other independent 
#variables constant. Remember to keep in mind the units which your variables are measured in.

##R-squared

#The R-squared of the regression is the fraction of the variation in your dependent variable that is accounted 
#for (or predicted by) your independent variables. (In regression with a single independent variable, it is the 
#same as the square of the correlation between your dependent and independent variable.) The R-squared is generally 
#of secondary importance, unless your main concern is using the regression equation to make accurate predictions. 
#The P value tells you how confident you can be that each individual variable has some correlation with the dependent 
#variable, which is the important thing.

#Another number to be aware of is the P value for the regression as a whole. Because your independent variables
#may be correlated, a condition known as multicollinearity, the coefficients on individual variables may be 
#insignificant when the regression as a whole is significant. Intuitively, this is because highly correlated 
#independent variables are explaining the same part of the variation in the dependent variable, so their 
#explanatory power and the significance of their coefficients is "divided up" between them.

# %%
###ANALYSIS FOR Fragile and conflict affected situations

# %%
df_merge[df_merge["Country Name"]=="Fragile and conflict affected situations"].describe()
# Out:
#              Year  ODA Received  Labor Force (%Population)  \
# count    10.00000  1.000000e+01                  10.000000
# mean   2014.50000  4.571475e+10                  63.423083
# std       3.02765  7.968928e+09                   0.782910
# min    2010.00000  3.763224e+10                  62.752769
# 25%    2012.25000  4.004361e+10                  62.900580
# 50%    2014.50000  4.262454e+10                  63.066350
# 75%    2016.75000  5.109749e+10                  63.770602
# max    2019.00000  5.873507e+10                  64.843223
#
#        Debt Policy Rating    Population  Life Expectancy (Years)  \
# count           10.000000  1.000000e+01                10.000000
# mean             2.980457  8.211701e+08                60.935553
# std              0.156563  5.827550e+07                 1.135814
# min              2.758065  7.354482e+08                59.120581
# 25%              2.825000  7.775428e+08                60.122202
# 50%              3.056989  8.208929e+08                61.032256
# 75%              3.083333  8.641507e+08                61.812213
# max              3.166667  9.087395e+08                62.480088
#
#        Trade (%GDP)  Inflation  FDI (%GDP)  GDP per capita  \
# count     10.000000  10.000000   10.000000       10.000000
# mean      51.186789   2.963943    1.841479     2007.536573
# std        5.185176   1.470797    0.480353      285.634941
# min       42.876645   1.476720    1.066310     1656.735971
# 25%       47.639478   1.932807    1.546953     1784.835628
# 50%       51.741190   2.335915    1.790504     1960.421316
# 75%       54.756087   3.468777    2.038660     2273.179899
# max       59.423832   5.478296    2.637052     2414.418207
#
#        Transparency_Accountability_Corruption_PublicSector_Rating
# count                                          10.000000
# mean                                            2.582876
# std                                             0.040864
# min                                             2.500000
# 25%                                             2.568519
# 50%                                             2.583333
# 75%                                             2.599194
# max                                             2.642857

# %%
df_merge[df_merge["Country Name"]=="Fragile and conflict affected situations"].corr()
# Out:
#                                                         Year  ODA Received  \
# Year                                                1.000000      0.897524
# ODA Received                                        0.897524      1.000000
# Labor Force (%Population)                          -0.876975     -0.636804
# Debt Policy Rating                                 -0.913003     -0.926542
# Population                                          0.999962      0.899510
# Life Expectancy (Years)                             0.996947      0.868181
# Trade (%GDP)                                       -0.593967     -0.270663
# Inflation                                          -0.693710     -0.487233
# FDI (%GDP)                                         -0.558457     -0.461779
# GDP per capita                                     -0.737775     -0.669962
# Transparency_Accountability_Corruption_PublicSe... -0.608375     -0.642785
#
#                                                     Labor Force (%Population)  \
# Year                                                                -0.876975
# ODA Received                                                        -0.636804
# Labor Force (%Population)                                            1.000000
# Debt Policy Rating                                                   0.713049
# Population                                                          -0.873676
# Life Expectancy (Years)                                             -0.909699
# Trade (%GDP)                                                         0.830290
# Inflation                                                            0.780976
# FDI (%GDP)                                                           0.615576
# GDP per capita                                                       0.576801
# Transparency_Accountability_Corruption_PublicSe...                   0.473534
#
#                                                     Debt Policy Rating  \
# Year                                                         -0.913003
# ODA Received                                                 -0.926542
# Labor Force (%Population)                                     0.713049
# Debt Policy Rating                                            1.000000
# Population                                                   -0.913545
# Life Expectancy (Years)                                      -0.894692
# Trade (%GDP)                                                  0.407232
# Inflation                                                     0.465103
# FDI (%GDP)                                                    0.309666
# GDP per capita                                                0.771993
# Transparency_Accountability_Corruption_PublicSe...            0.733230
#
#                                                     Population  \
# Year                                                  0.999962
# ODA Received                                          0.899510
# Labor Force (%Population)                            -0.873676
# Debt Policy Rating                                   -0.913545
# Population                                            1.000000
# Life Expectancy (Years)                               0.996302
# Trade (%GDP)                                         -0.590331
# Inflation                                            -0.693027
# FDI (%GDP)                                           -0.559314
# GDP per capita                                       -0.737339
# Transparency_Accountability_Corruption_PublicSe...   -0.609973
#
#                                                     Life Expectancy (Years)  \
# Year                                                               0.996947
# ODA Received                                                       0.868181
# Labor Force (%Population)                                         -0.909699
# Debt Policy Rating                                                -0.894692
# Population                                                         0.996302
# Life Expectancy (Years)                                            1.000000
# Trade (%GDP)                                                      -0.639771
# Inflation                                                         -0.714919
# FDI (%GDP)                                                        -0.567277
# GDP per capita                                                    -0.731825
# Transparency_Accountability_Corruption_PublicSe...                -0.587466
#
#                                                     Trade (%GDP)  Inflation  \
# Year                                                   -0.593967  -0.693710
# ODA Received                                           -0.270663  -0.487233
# Labor Force (%Population)                               0.830290   0.780976
# Debt Policy Rating                                      0.407232   0.465103
# Population                                             -0.590331  -0.693027
# Life Expectancy (Years)                                -0.639771  -0.714919
# Trade (%GDP)                                            1.000000   0.839596
# Inflation                                               0.839596   1.000000
# FDI (%GDP)                                              0.455617   0.743563
# GDP per capita                                          0.561015   0.480048
# Transparency_Accountability_Corruption_PublicSe...      0.420211   0.505991
#
#                                                     FDI (%GDP)  \
# Year                                                 -0.558457
# ODA Received                                         -0.461779
# Labor Force (%Population)                             0.615576
# Debt Policy Rating                                    0.309666
# Population                                           -0.559314
# Life Expectancy (Years)                              -0.567277
# Trade (%GDP)                                          0.455617
# Inflation                                             0.743563
# FDI (%GDP)                                            1.000000
# GDP per capita                                       -0.000844
# Transparency_Accountability_Corruption_PublicSe...    0.112826
#
#                                                     GDP per capita  \
# Year                                                     -0.737775
# ODA Received                                             -0.669962
# Labor Force (%Population)                                 0.576801
# Debt Policy Rating                                        0.771993
# Population                                               -0.737339
# Life Expectancy (Years)                                  -0.731825
# Trade (%GDP)                                              0.561015
# Inflation                                                 0.480048
# FDI (%GDP)                                               -0.000844
# GDP per capita                                            1.000000
# Transparency_Accountability_Corruption_PublicSe...        0.636102
#
#                                                     Transparency_Accountability_Corruption_PublicSector_Rating
# Year                                                                                        -0.608375
# ODA Received                                                                                -0.642785
# Labor Force (%Population)                                                                    0.473534
# Debt Policy Rating                                                                           0.733230
# Population                                                                                  -0.609973
# Life Expectancy (Years)                                                                     -0.587466
# Trade (%GDP)                                                                                 0.420211
# Inflation                                                                                    0.505991
# FDI (%GDP)                                                                                   0.112826
# GDP per capita                                                                               0.636102
# Transparency_Accountability_Corruption_PublicSe...                                           1.000000

# %%
##Observations: 
##1) Analysing GDP, we see that only FDI has a weak corretalion with it. 
##2) FDI has a relatevely strong negatively corr with ODA received. That means that if we increase ODA, the GDP decreases
##3) GDP has littler (almost none) corr with FDI
##4) ODA has a strong negatively corr with liability, which means the higher the rate, the lower ODA -- weird. Same with debt rate
##ODA is not that correlated with trade (oppenness to the market)

# %%
df_fragile=df_merge[df_merge["Country Name"]=="Fragile and conflict affected situations"]
#df_fragile.head(2)

# %%
df_fragile["Debt Policy Rating"].isnull().sum()
# Out:
# 0

# %%
df_fragile.columns
# Out:
# Index(['Country Name', 'Year', 'ODA Received', 'Labor Force (%Population)',
#        'Debt Policy Rating', 'Population', 'Life Expectancy (Years)',
#        'Trade (%GDP)', 'Inflation', 'FDI (%GDP)', 'GDP per capita',
#        'Transparency_Accountability_Corruption_PublicSector_Rating'],
#       dtype='object')

# %%
X_fragile = df_fragile[["Year", "FDI (%GDP)", "ODA Received", "Labor Force (%Population)", "Population", "Life Expectancy (Years)", "Trade (%GDP)", "Inflation", "Transparency_Accountability_Corruption_PublicSector_Rating", "Debt Policy Rating"]]
X_fragile = sm.add_constant(X_fragile)
y_fragile = df_fragile['GDP per capita']
model_fragile = sm.OLS(y_fragile,X_fragile).fit()

model_fragile.summary()
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1749: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1671: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         GDP per capita   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                   -inf
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 24 Feb 2022   Prob (F-statistic):                nan
# Time:                        16:38:00   Log-Likelihood:                 103.48
# No. Observations:                  10   AIC:                            -187.0
# Df Residuals:                       0   BIC:                            -183.9
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          1.2286        inf          0        nan         nan         nan
# Year                                                          92.8070        inf          0        nan         nan         nan
# FDI (%GDP)                                                  -136.2840        inf         -0        nan         nan         nan
# ODA Received                                               -3.309e-08        inf         -0        nan         nan         nan
# Labor Force (%Population)                                  -1029.1229        inf         -0        nan         nan         nan
# Population                                                  3.227e-05        inf          0        nan         nan         nan
# Life Expectancy (Years)                                    -2443.4627        inf         -0        nan         nan         nan
# Trade (%GDP)                                                  79.7218        inf          0        nan         nan         nan
# Inflation                                                    -88.6584        inf         -0        nan         nan         nan
# Transparency_Accountability_Corruption_PublicSector_Rating   751.1944        inf          0        nan         nan         nan
# Debt Policy Rating                                          -431.5275        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                        1.226   Durbin-Watson:                   0.671
# Prob(Omnibus):                  0.542   Jarque-Bera (JB):                0.687
# Skew:                          -0.088   Prob(JB):                        0.709
# Kurtosis:                       1.728   Cond. No.                     1.60e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 1.6e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
##we can see that in this case the coef of ODA is not that significant in the regression line. The other variables
##have more strong coef, like life expec, liability, FDI.

# %%
model_fragile.predict(X_fragile)
# Out:
# 0     2296.709846
# 5     2042.129222
# 10    2249.296810
# 15    2281.140927
# 20    2414.418198
# 25    1878.713408
# 30    1656.735965
# 35    1657.340919
# 40    1770.231047
# 45    1828.649326
# dtype: float64

# %%
y_fragile
# Out:
# 0     2296.709859
# 5     2042.129223
# 10    2249.296816
# 15    2281.140927
# 20    2414.418207
# 25    1878.713408
# 30    1656.735971
# 35    1657.340925
# 40    1770.231058
# 45    1828.649338
# Name: GDP per capita, dtype: float64

# %%
np.sqrt(mean_squared_error(y_fragile, model_fragile.predict(X_fragile)))

##that means that my model is making an error by only 6 dollars which is really small
##our model predicts really well
# Out:
# 7.755508482703528e-06

# %%
#Lets try to do a regression with ODA only

X_ODA_fragile = df_fragile[["ODA Received", "Year"]]
X_ODA_fragile = sm.add_constant(X_ODA_fragile)
y_ODA_fragile = df_fragile['GDP per capita']
model_ODA_fragile = sm.OLS(y_ODA_fragile,X_ODA_fragile).fit()

model_ODA_fragile.summary()

##our model is not that good since R-squared is small, and the coef of ODA continues small, so it doesnt explain GDP that much
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         GDP per capita   R-squared:                       0.545
# Model:                            OLS   Adj. R-squared:                  0.415
# Method:                 Least Squares   F-statistic:                     4.186
# Date:                Thu, 24 Feb 2022   Prob (F-statistic):             0.0637
# Time:                        16:38:00   Log-Likelihood:                -66.277
# No. Observations:                  10   AIC:                             138.6
# Df Residuals:                       7   BIC:                             139.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1.355e+05   1.09e+05      1.242      0.254   -1.22e+05    3.93e+05
# ODA Received -1.436e-09   2.07e-08     -0.069      0.947   -5.05e-08    4.76e-08
# Year           -66.2104     54.568     -1.213      0.264    -195.243      62.822
# ==============================================================================
# Omnibus:                        0.607   Durbin-Watson:                   1.368
# Prob(Omnibus):                  0.738   Jarque-Bera (JB):                0.497
# Skew:                           0.438   Prob(JB):                        0.780
# Kurtosis:                       2.348   Cond. No.                     7.31e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.31e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
###ANALYSIS FOR Heavily indebted poor countries (HIPC)

# %%
df_merge[df_merge["Country Name"]=="Heavily indebted poor countries (HIPC)"].describe()
# Out:
#              Year  ODA Received  Labor Force (%Population)  \
# count    10.00000  1.000000e+01                  10.000000
# mean   2014.50000  4.077596e+10                  70.762612
# std       3.02765  2.764753e+09                   0.562371
# min    2010.00000  3.660734e+10                  70.206722
# 25%    2012.25000  3.876375e+10                  70.306938
# 50%    2014.50000  4.064372e+10                  70.560671
# 75%    2016.75000  4.347785e+10                  71.059186
# max    2019.00000  4.415181e+10                  71.819260
#
#        Debt Policy Rating    Population  Life Expectancy (Years)  \
# count           10.000000  1.000000e+01                10.000000
# mean             3.266856  7.101248e+08                61.420539
# std              0.098871  5.981108e+07                 1.567590
# min              3.118421  6.242193e+08                58.858947
# 25%              3.187500  6.648987e+08                60.317508
# 50%              3.279872  7.082325e+08                61.593634
# 75%              3.342105  7.539264e+08                62.642325
# max              3.394737  8.017080e+08                63.486455
#
#        Trade (%GDP)  Inflation  FDI (%GDP)  GDP per capita  \
# count     10.000000  10.000000   10.000000       10.000000
# mean      58.242670   4.572376    4.466506      924.323782
# std        5.041891   1.242817    0.766065       59.095683
# min       52.794768   2.685374    3.420102      808.891113
# 25%       53.600741   3.823017    3.802923      884.258279
# 50%       57.008678   4.681777    4.413247      933.993131
# 75%       63.218593   5.115412    5.010521      977.971050
# max       65.010992   6.429397    5.664416      985.186284
#
#        Transparency_Accountability_Corruption_PublicSector_Rating
# count                                          10.000000
# mean                                            2.679801
# std                                             0.032966
# min                                             2.631579
# 25%                                             2.658962
# 50%                                             2.666607
# 75%                                             2.697368
# max                                             2.736842

# %%
df_merge[df_merge["Country Name"]=="Heavily indebted poor countries (HIPC)"].corr()
# Out:
#                                                         Year  ODA Received  \
# Year                                                1.000000     -0.335798
# ODA Received                                       -0.335798      1.000000
# Labor Force (%Population)                          -0.949552      0.574783
# Debt Policy Rating                                 -0.601910     -0.377637
# Population                                          0.999539     -0.310699
# Life Expectancy (Years)                             0.994714     -0.421213
# Trade (%GDP)                                       -0.933581      0.551893
# Inflation                                          -0.740676      0.218526
# FDI (%GDP)                                         -0.817701      0.268503
# GDP per capita                                      0.781153     -0.346703
# Transparency_Accountability_Corruption_PublicSe... -0.430333     -0.091311
#
#                                                     Labor Force (%Population)  \
# Year                                                                -0.949552
# ODA Received                                                         0.574783
# Labor Force (%Population)                                            1.000000
# Debt Policy Rating                                                   0.341482
# Population                                                          -0.939782
# Life Expectancy (Years)                                             -0.976089
# Trade (%GDP)                                                         0.927684
# Inflation                                                            0.646699
# FDI (%GDP)                                                           0.697082
# GDP per capita                                                      -0.813889
# Transparency_Accountability_Corruption_PublicSe...                   0.298275
#
#                                                     Debt Policy Rating  \
# Year                                                         -0.601910
# ODA Received                                                 -0.377637
# Labor Force (%Population)                                     0.341482
# Debt Policy Rating                                            1.000000
# Population                                                   -0.623467
# Life Expectancy (Years)                                      -0.525440
# Trade (%GDP)                                                  0.492804
# Inflation                                                     0.450279
# FDI (%GDP)                                                    0.648765
# GDP per capita                                               -0.208715
# Transparency_Accountability_Corruption_PublicSe...            0.733856
#
#                                                     Population  \
# Year                                                  0.999539
# ODA Received                                         -0.310699
# Labor Force (%Population)                            -0.939782
# Debt Policy Rating                                   -0.623467
# Population                                            1.000000
# Life Expectancy (Years)                               0.991146
# Trade (%GDP)                                         -0.929151
# Inflation                                            -0.746479
# FDI (%GDP)                                           -0.824764
# GDP per capita                                        0.772159
# Transparency_Accountability_Corruption_PublicSe...   -0.442710
#
#                                                     Life Expectancy (Years)  \
# Year                                                               0.994714
# ODA Received                                                      -0.421213
# Labor Force (%Population)                                         -0.976089
# Debt Policy Rating                                                -0.525440
# Population                                                         0.991146
# Life Expectancy (Years)                                            1.000000
# Trade (%GDP)                                                      -0.944352
# Inflation                                                         -0.717996
# FDI (%GDP)                                                        -0.791047
# GDP per capita                                                     0.804213
# Transparency_Accountability_Corruption_PublicSe...                -0.387319
#
#                                                     Trade (%GDP)  Inflation  \
# Year                                                   -0.933581  -0.740676
# ODA Received                                            0.551893   0.218526
# Labor Force (%Population)                               0.927684   0.646699
# Debt Policy Rating                                      0.492804   0.450279
# Population                                             -0.929151  -0.746479
# Life Expectancy (Years)                                -0.944352  -0.717996
# Trade (%GDP)                                            1.000000   0.729366
# Inflation                                               0.729366   1.000000
# FDI (%GDP)                                              0.863700   0.801205
# GDP per capita                                         -0.678391  -0.615108
# Transparency_Accountability_Corruption_PublicSe...      0.423172   0.196788
#
#                                                     FDI (%GDP)  \
# Year                                                 -0.817701
# ODA Received                                          0.268503
# Labor Force (%Population)                             0.697082
# Debt Policy Rating                                    0.648765
# Population                                           -0.824764
# Life Expectancy (Years)                              -0.791047
# Trade (%GDP)                                          0.863700
# Inflation                                             0.801205
# FDI (%GDP)                                            1.000000
# GDP per capita                                       -0.494456
# Transparency_Accountability_Corruption_PublicSe...    0.385924
#
#                                                     GDP per capita  \
# Year                                                      0.781153
# ODA Received                                             -0.346703
# Labor Force (%Population)                                -0.813889
# Debt Policy Rating                                       -0.208715
# Population                                                0.772159
# Life Expectancy (Years)                                   0.804213
# Trade (%GDP)                                             -0.678391
# Inflation                                                -0.615108
# FDI (%GDP)                                               -0.494456
# GDP per capita                                            1.000000
# Transparency_Accountability_Corruption_PublicSe...        0.075615
#
#                                                     Transparency_Accountability_Corruption_PublicSector_Rating
# Year                                                                                        -0.430333
# ODA Received                                                                                -0.091311
# Labor Force (%Population)                                                                    0.298275
# Debt Policy Rating                                                                           0.733856
# Population                                                                                  -0.442710
# Life Expectancy (Years)                                                                     -0.387319
# Trade (%GDP)                                                                                 0.423172
# Inflation                                                                                    0.196788
# FDI (%GDP)                                                                                   0.385924
# GDP per capita                                                                               0.075615
# Transparency_Accountability_Corruption_PublicSe...                                           1.000000

# %%
#Observations: 
# 1) In this case, GDP is significanly correlated with all the indep variables, except liability 
#(transparancy, accountability etc). 
# 2) For ODA and Debt policy rating, the corr is not that strong
# 3) GDP is strong negatively related to trade and labor force
# 4) ODA is positively and kind of strong related to labor force and trade

# %%
df_heavily=df_merge[df_merge["Country Name"]=="Heavily indebted poor countries (HIPC)"]
#df_heavily.head(2)

# %%
X_heavily = df_heavily[["Year", "FDI (%GDP)", "ODA Received", "Labor Force (%Population)", "Population", "Life Expectancy (Years)", "Trade (%GDP)", "Inflation", "Transparency_Accountability_Corruption_PublicSector_Rating", "Debt Policy Rating"]]
X_heavily = sm.add_constant(X_heavily)
y_heavily = df_heavily['GDP per capita']
model_heavily = sm.OLS(y_heavily,X_heavily).fit()

model_heavily.summary()

#when we remove "Transparency_Accountability_Corruption_PublicSector_Rating" our model gets a 0.98 R^2
#we can see that the coef of ODA is small which means that we cant explain growth by ODA
#Important coefs are lufe expec(positively), liability(negatively), labor force(positivel)
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1749: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1671: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         GDP per capita   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                   -inf
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 24 Feb 2022   Prob (F-statistic):                nan
# Time:                        16:38:00   Log-Likelihood:                 124.02
# No. Observations:                  10   AIC:                            -228.0
# Df Residuals:                       0   BIC:                            -225.0
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -0.2205        inf         -0        nan         nan         nan
# Year                                                         -45.3082        inf         -0        nan         nan         nan
# FDI (%GDP)                                                   -78.6878        inf         -0        nan         nan         nan
# ODA Received                                                5.467e-08        inf          0        nan         nan         nan
# Labor Force (%Population)                                    439.8260        inf          0        nan         nan         nan
# Population                                                 -2.781e-05        inf         -0        nan         nan         nan
# Life Expectancy (Years)                                     1318.8203        inf          0        nan         nan         nan
# Trade (%GDP)                                                   6.3735        inf          0        nan         nan         nan
# Inflation                                                    -44.5975        inf         -0        nan         nan         nan
# Transparency_Accountability_Corruption_PublicSector_Rating  -749.4534        inf         -0        nan         nan         nan
# Debt Policy Rating                                           -66.7076        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                        0.535   Durbin-Watson:                   1.479
# Prob(Omnibus):                  0.765   Jarque-Bera (JB):                0.516
# Skew:                           0.128   Prob(JB):                        0.773
# Kurtosis:                       1.917   Cond. No.                     7.95e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 7.95e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
np.sqrt(mean_squared_error(y_heavily, model_heavily.predict(X_heavily)))

##that means that my model is making an error by only 0.55 dollars which is really small
#our model predicts really well
# Out:
# 9.945088761785094e-07

# %%
##Lets try to do a regression with oda only

X_ODA_heavily = df_heavily[["ODA Received", "Year"]]
X_ODA_heavily = sm.add_constant(X_ODA_heavily)
y_ODA_heavily = df_heavily['GDP per capita']
model_ODA_heavily = sm.OLS(y_ODA_heavily,X_ODA_heavily).fit()

model_ODA_heavily.summary()

##our model is ok- low R squared is ok but coef ODA is still low
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         GDP per capita   R-squared:                       0.618
# Model:                            OLS   Adj. R-squared:                  0.509
# Method:                 Least Squares   F-statistic:                     5.668
# Date:                Thu, 24 Feb 2022   Prob (F-statistic):             0.0344
# Time:                        16:38:00   Log-Likelihood:                -49.640
# No. Observations:                  10   AIC:                             105.3
# Df Residuals:                       7   BIC:                             106.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -2.845e+04   9823.453     -2.896      0.023   -5.17e+04   -5223.292
# ODA Received -2.033e-09    5.3e-09     -0.384      0.713   -1.46e-08    1.05e-08
# Year            14.6236      4.839      3.022      0.019       3.180      26.067
# ==============================================================================
# Omnibus:                        0.762   Durbin-Watson:                   1.330
# Prob(Omnibus):                  0.683   Jarque-Bera (JB):                0.557
# Skew:                           0.489   Prob(JB):                        0.757
# Kurtosis:                       2.382   Cond. No.                     3.07e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.07e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
###ANALYSIS FOR Least developed countries: UN classification

# %%
df_merge[df_merge["Country Name"]=="Least developed countries: UN classification"].describe()
# Out:
#              Year  ODA Received  Labor Force (%Population)  \
# count    10.00000  1.000000e+01                  10.000000
# mean   2014.50000  4.686216e+10                  68.808570
# std       3.02765  4.645052e+09                   0.381492
# min    2010.00000  4.310961e+10                  68.347334
# 25%    2012.25000  4.355384e+10                  68.553184
# 50%    2014.50000  4.424509e+10                  68.750600
# 75%    2016.75000  4.870431e+10                  68.946257
# max    2019.00000  5.569676e+10                  69.540799
#
#        Debt Policy Rating    Population  Life Expectancy (Years)  \
# count           10.000000  1.000000e+01                10.000000
# mean             3.200272  9.321086e+08                63.579786
# std              0.080102  6.627050e+07                 1.336801
# min              3.076087  8.366148e+08                61.388934
# 25%              3.122222  8.820988e+08                62.644107
# 50%              3.230676  9.301771e+08                63.728405
# 75%              3.269380  9.806690e+08                64.617354
# max              3.288889  1.033389e+09                65.345421
#
#        Trade (%GDP)  Inflation  FDI (%GDP)  GDP per capita  \
# count     10.000000  10.000000   10.000000       10.000000
# mean      54.914709   4.922109    2.786815      982.684187
# std        4.274566   1.250266    0.767398       82.461361
# min       49.433923   2.869094    1.730708      805.306314
# 25%       51.294379   4.074295    2.224077      940.610166
# 50%       55.045780   5.129141    2.811608     1000.507413
# 75%       58.939385   5.564520    3.084538     1045.902542
# max       60.092158   6.788194    4.088185     1071.583498
#
#        Transparency_Accountability_Corruption_PublicSector_Rating
# count                                          10.000000
# mean                                            2.689766
# std                                             0.032122
# min                                             2.641304
# 25%                                             2.668478
# 50%                                             2.688889
# 75%                                             2.699419
# max                                             2.744186

# %%
df_merge[df_merge["Country Name"]=="Least developed countries: UN classification"].corr()
# Out:
#                                                         Year  ODA Received  \
# Year                                                1.000000      0.750237
# ODA Received                                        0.750237      1.000000
# Labor Force (%Population)                          -0.703457     -0.163734
# Debt Policy Rating                                 -0.805905     -0.794029
# Population                                          0.999610      0.763155
# Life Expectancy (Years)                             0.994648      0.696595
# Trade (%GDP)                                       -0.823482     -0.308661
# Inflation                                          -0.814533     -0.685685
# FDI (%GDP)                                         -0.603462     -0.836365
# GDP per capita                                      0.857965      0.618799
# Transparency_Accountability_Corruption_PublicSe... -0.718452     -0.666461
#
#                                                     Labor Force (%Population)  \
# Year                                                                -0.703457
# ODA Received                                                        -0.163734
# Labor Force (%Population)                                            1.000000
# Debt Policy Rating                                                   0.261598
# Population                                                          -0.685317
# Life Expectancy (Years)                                             -0.766379
# Trade (%GDP)                                                         0.750201
# Inflation                                                            0.553804
# FDI (%GDP)                                                          -0.006886
# GDP per capita                                                      -0.789960
# Transparency_Accountability_Corruption_PublicSe...                   0.303523
#
#                                                     Debt Policy Rating  \
# Year                                                         -0.805905
# ODA Received                                                 -0.794029
# Labor Force (%Population)                                     0.261598
# Debt Policy Rating                                            1.000000
# Population                                                   -0.816569
# Life Expectancy (Years)                                      -0.760304
# Trade (%GDP)                                                  0.613971
# Inflation                                                     0.527847
# FDI (%GDP)                                                    0.819519
# GDP per capita                                               -0.486802
# Transparency_Accountability_Corruption_PublicSe...            0.833661
#
#                                                     Population  \
# Year                                                  0.999610
# ODA Received                                          0.763155
# Labor Force (%Population)                            -0.685317
# Debt Policy Rating                                   -0.816569
# Population                                            1.000000
# Life Expectancy (Years)                               0.991377
# Trade (%GDP)                                         -0.817218
# Inflation                                            -0.818531
# FDI (%GDP)                                           -0.618527
# GDP per capita                                        0.848543
# Transparency_Accountability_Corruption_PublicSe...   -0.723099
#
#                                                     Life Expectancy (Years)  \
# Year                                                               0.994648
# ODA Received                                                       0.696595
# Labor Force (%Population)                                         -0.766379
# Debt Policy Rating                                                -0.760304
# Population                                                         0.991377
# Life Expectancy (Years)                                            1.000000
# Trade (%GDP)                                                      -0.841964
# Inflation                                                         -0.795508
# FDI (%GDP)                                                        -0.543270
# GDP per capita                                                     0.886598
# Transparency_Accountability_Corruption_PublicSe...                -0.696322
#
#                                                     Trade (%GDP)  Inflation  \
# Year                                                   -0.823482  -0.814533
# ODA Received                                           -0.308661  -0.685685
# Labor Force (%Population)                               0.750201   0.553804
# Debt Policy Rating                                      0.613971   0.527847
# Population                                             -0.817218  -0.818531
# Life Expectancy (Years)                                -0.841964  -0.795508
# Trade (%GDP)                                            1.000000   0.602901
# Inflation                                               0.602901   1.000000
# FDI (%GDP)                                              0.285167   0.466133
# GDP per capita                                         -0.611918  -0.709884
# Transparency_Accountability_Corruption_PublicSe...      0.634146   0.550892
#
#                                                     FDI (%GDP)  \
# Year                                                 -0.603462
# ODA Received                                         -0.836365
# Labor Force (%Population)                            -0.006886
# Debt Policy Rating                                    0.819519
# Population                                           -0.618527
# Life Expectancy (Years)                              -0.543270
# Trade (%GDP)                                          0.285167
# Inflation                                             0.466133
# FDI (%GDP)                                            1.000000
# GDP per capita                                       -0.380517
# Transparency_Accountability_Corruption_PublicSe...    0.605431
#
#                                                     GDP per capita  \
# Year                                                      0.857965
# ODA Received                                              0.618799
# Labor Force (%Population)                                -0.789960
# Debt Policy Rating                                       -0.486802
# Population                                                0.848543
# Life Expectancy (Years)                                   0.886598
# Trade (%GDP)                                             -0.611918
# Inflation                                                -0.709884
# FDI (%GDP)                                               -0.380517
# GDP per capita                                            1.000000
# Transparency_Accountability_Corruption_PublicSe...       -0.455665
#
#                                                     Transparency_Accountability_Corruption_PublicSector_Rating
# Year                                                                                        -0.718452
# ODA Received                                                                                -0.666461
# Labor Force (%Population)                                                                    0.303523
# Debt Policy Rating                                                                           0.833661
# Population                                                                                  -0.723099
# Life Expectancy (Years)                                                                     -0.696322
# Trade (%GDP)                                                                                 0.634146
# Inflation                                                                                    0.550892
# FDI (%GDP)                                                                                   0.605431
# GDP per capita                                                                              -0.455665
# Transparency_Accountability_Corruption_PublicSe...                                           1.000000

# %%
#Observations: 
# 1) In this case, GDP is significanly correlated with all the indep variables, being positively with ODA
# 2) ODA is strong negatively corr with debt policy rate (if one increases, other decreases - weird), liability (weird), FDI

# %%
df_least=df_merge[df_merge["Country Name"]=="Least developed countries: UN classification"]
#df_least.head(2)

# %%
X_least = df_least[["Year", "FDI (%GDP)", "ODA Received", "Labor Force (%Population)", "Population", "Life Expectancy (Years)", "Trade (%GDP)", "Inflation", "Transparency_Accountability_Corruption_PublicSector_Rating", "Debt Policy Rating"]]
X_least = sm.add_constant(X_least)
y_least = df_least['GDP per capita']
model_least = sm.OLS(y_least,X_least).fit()

model_least.summary()


#really good predict model
#coef of ODA really small
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1749: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1671: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         GDP per capita   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                   -inf
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 24 Feb 2022   Prob (F-statistic):                nan
# Time:                        16:38:00   Log-Likelihood:                 78.130
# No. Observations:                  10   AIC:                            -136.3
# Df Residuals:                       0   BIC:                            -133.2
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                        -11.6307        inf         -0        nan         nan         nan
# Year                                                         -60.2981        inf         -0        nan         nan         nan
# FDI (%GDP)                                                   125.7231        inf          0        nan         nan         nan
# ODA Received                                                7.324e-08        inf          0        nan         nan         nan
# Labor Force (%Population)                                    500.3043        inf          0        nan         nan         nan
# Population                                                 -4.475e-05        inf         -0        nan         nan         nan
# Life Expectancy (Years)                                     1970.3984        inf          0        nan         nan         nan
# Trade (%GDP)                                                 -56.6015        inf         -0        nan         nan         nan
# Inflation                                                   -189.7056        inf         -0        nan         nan         nan
# Transparency_Accountability_Corruption_PublicSector_Rating  7650.9086        inf          0        nan         nan         nan
# Debt Policy Rating                                         -4949.9393        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                        4.994   Durbin-Watson:                   0.422
# Prob(Omnibus):                  0.082   Jarque-Bera (JB):                2.239
# Skew:                           1.156   Prob(JB):                        0.326
# Kurtosis:                       3.170   Cond. No.                     3.00e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large,  3e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
np.sqrt(mean_squared_error(y_least, model_least.predict(X_least)))

#our model is wrong by 13 dollars
# Out:
# 9.78635665175274e-05

# %%
#Lets try to do regression for ODA only

X_ODA_least = df_least[["Year", "ODA Received"]]
X_ODA_least = sm.add_constant(X_ODA_least)
y_ODA_least = df_least['GDP per capita']
model_ODA_least = sm.OLS(y_ODA_least,X_ODA_least).fit()

model_ODA_least.summary()

#our R squared is really good, but coef is still very small
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         GDP per capita   R-squared:                       0.738
# Model:                            OLS   Adj. R-squared:                  0.663
# Method:                 Least Squares   F-statistic:                     9.834
# Date:                Thu, 24 Feb 2022   Prob (F-statistic):            0.00926
# Time:                        16:38:00   Log-Likelihood:                -51.098
# No. Observations:                  10   AIC:                             108.2
# Df Residuals:                       7   BIC:                             109.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -4.839e+04   1.59e+04     -3.046      0.019    -8.6e+04   -1.08e+04
# Year            24.5305      7.977      3.075      0.018       5.668      43.393
# ODA Received  -1.01e-09    5.2e-09     -0.194      0.851   -1.33e-08    1.13e-08
# ==============================================================================
# Omnibus:                        0.272   Durbin-Watson:                   1.186
# Prob(Omnibus):                  0.873   Jarque-Bera (JB):                0.062
# Skew:                           0.101   Prob(JB):                        0.970
# Kurtosis:                       2.673   Cond. No.                     4.94e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.94e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
###ANALYSIS FOR Low income

# %%
df_merge[df_merge["Country Name"]=="Low income"].describe()
# Out:
#              Year  ODA Received  Labor Force (%Population)  \
# count    10.00000  1.000000e+01                  10.000000
# mean   2014.50000  3.930566e+10                  69.102038
# std       3.02765  6.671897e+09                   0.437835
# min    2010.00000  3.308972e+10                  68.633303
# 25%    2012.25000  3.458936e+10                  68.794421
# 50%    2014.50000  3.591833e+10                  68.920260
# 75%    2016.75000  4.391231e+10                  69.339471
# max    2019.00000  4.996988e+10                  69.930830
#
#        Debt Policy Rating    Population  Life Expectancy (Years)  \
# count           10.000000  1.000000e+01                10.000000
# mean             3.017178  5.784299e+08                61.901038
# std              0.138670  4.495772e+07                 1.342270
# min              2.820000  5.137833e+08                59.739740
# 25%              2.875000  5.446835e+08                60.951074
# 50%              3.083333  5.767262e+08                62.014996
# 75%              3.120924  6.110464e+08                62.932558
# max              3.173913  6.478708e+08                63.727749
#
#        Trade (%GDP)  Inflation  FDI (%GDP)  GDP per capita  \
# count     10.000000  10.000000   10.000000       10.000000
# mean      51.000582   5.576399    3.991012      745.232088
# std        4.928349   1.794328    1.043714      138.305241
# min       44.145136   2.825100    2.652487      646.104636
# 25%       47.420681   4.484901    3.373380      678.806773
# 50%       50.145773   5.296348    3.610227      711.388704
# 75%       54.222112   6.829835    4.571830      737.305918
# max       59.760608   8.279537    6.161376     1125.394877
#
#        Transparency_Accountability_Corruption_PublicSector_Rating
# count                                          10.000000
# mean                                            2.457710
# std                                             0.067499
# min                                             2.360000
# 25%                                             2.417500
# 50%                                             2.437500
# 75%                                             2.489583
# max                                             2.586957

# %%
df_merge[df_merge["Country Name"]=="Low income"].corr()
# Out:
#                                                         Year  ODA Received  \
# Year                                                1.000000      0.923308
# ODA Received                                        0.923308      1.000000
# Labor Force (%Population)                          -0.948761     -0.764799
# Debt Policy Rating                                 -0.861626     -0.931845
# Population                                          0.999384      0.933982
# Life Expectancy (Years)                             0.996783      0.893933
# Trade (%GDP)                                       -0.777356     -0.497657
# Inflation                                          -0.406880     -0.389790
# FDI (%GDP)                                         -0.370631     -0.461849
# GDP per capita                                     -0.662331     -0.466694
# Transparency_Accountability_Corruption_PublicSe... -0.759813     -0.574187
#
#                                                     Labor Force (%Population)  \
# Year                                                                -0.948761
# ODA Received                                                        -0.764799
# Labor Force (%Population)                                            1.000000
# Debt Policy Rating                                                   0.701779
# Population                                                          -0.937900
# Life Expectancy (Years)                                             -0.969956
# Trade (%GDP)                                                         0.891800
# Inflation                                                            0.355663
# FDI (%GDP)                                                           0.233112
# GDP per capita                                                       0.778283
# Transparency_Accountability_Corruption_PublicSe...                   0.809611
#
#                                                     Debt Policy Rating  \
# Year                                                         -0.861626
# ODA Received                                                 -0.931845
# Labor Force (%Population)                                     0.701779
# Debt Policy Rating                                            1.000000
# Population                                                   -0.871276
# Life Expectancy (Years)                                      -0.833990
# Trade (%GDP)                                                  0.447851
# Inflation                                                     0.231080
# FDI (%GDP)                                                    0.356255
# GDP per capita                                                0.430797
# Transparency_Accountability_Corruption_PublicSe...            0.702021
#
#                                                     Population  \
# Year                                                  0.999384
# ODA Received                                          0.933982
# Labor Force (%Population)                            -0.937900
# Debt Policy Rating                                   -0.871276
# Population                                            1.000000
# Life Expectancy (Years)                               0.993390
# Trade (%GDP)                                         -0.759509
# Inflation                                            -0.416338
# FDI (%GDP)                                           -0.380542
# GDP per capita                                       -0.645653
# Transparency_Accountability_Corruption_PublicSe...   -0.747265
#
#                                                     Life Expectancy (Years)  \
# Year                                                               0.996783
# ODA Received                                                       0.893933
# Labor Force (%Population)                                         -0.969956
# Debt Policy Rating                                                -0.833990
# Population                                                         0.993390
# Life Expectancy (Years)                                            1.000000
# Trade (%GDP)                                                      -0.813937
# Inflation                                                         -0.383212
# FDI (%GDP)                                                        -0.337473
# GDP per capita                                                    -0.702770
# Transparency_Accountability_Corruption_PublicSe...                -0.783817
#
#                                                     Trade (%GDP)  Inflation  \
# Year                                                   -0.777356  -0.406880
# ODA Received                                           -0.497657  -0.389790
# Labor Force (%Population)                               0.891800   0.355663
# Debt Policy Rating                                      0.447851   0.231080
# Population                                             -0.759509  -0.416338
# Life Expectancy (Years)                                -0.813937  -0.383212
# Trade (%GDP)                                            1.000000   0.212184
# Inflation                                               0.212184   1.000000
# FDI (%GDP)                                              0.209844   0.540590
# GDP per capita                                          0.709465  -0.127969
# Transparency_Accountability_Corruption_PublicSe...      0.755282   0.081209
#
#                                                     FDI (%GDP)  \
# Year                                                 -0.370631
# ODA Received                                         -0.461849
# Labor Force (%Population)                             0.233112
# Debt Policy Rating                                    0.356255
# Population                                           -0.380542
# Life Expectancy (Years)                              -0.337473
# Trade (%GDP)                                          0.209844
# Inflation                                             0.540590
# FDI (%GDP)                                            1.000000
# GDP per capita                                       -0.358160
# Transparency_Accountability_Corruption_PublicSe...    0.078245
#
#                                                     GDP per capita  \
# Year                                                     -0.662331
# ODA Received                                             -0.466694
# Labor Force (%Population)                                 0.778283
# Debt Policy Rating                                        0.430797
# Population                                               -0.645653
# Life Expectancy (Years)                                  -0.702770
# Trade (%GDP)                                              0.709465
# Inflation                                                -0.127969
# FDI (%GDP)                                               -0.358160
# GDP per capita                                            1.000000
# Transparency_Accountability_Corruption_PublicSe...        0.623579
#
#                                                     Transparency_Accountability_Corruption_PublicSector_Rating
# Year                                                                                        -0.759813
# ODA Received                                                                                -0.574187
# Labor Force (%Population)                                                                    0.809611
# Debt Policy Rating                                                                           0.702021
# Population                                                                                  -0.747265
# Life Expectancy (Years)                                                                     -0.783817
# Trade (%GDP)                                                                                 0.755282
# Inflation                                                                                    0.081209
# FDI (%GDP)                                                                                   0.078245
# GDP per capita                                                                               0.623579
# Transparency_Accountability_Corruption_PublicSe...                                           1.000000

# %%
##observations:
## 1) GDP is storngly correlated with all variables, except inflation and fdi
## 2) GDP is not that strongly corr with ODA (negative - which means that if it increases, the other decreases - weird) and debt policy rate (positive)
## 3) ODA is negatively corr with trade (one of codition to give aid is opennes to trade - so weird), fdi and liability - weird

# %%
df_low=df_merge[df_merge["Country Name"]=="Low income"]
#df_low.head(2)

# %%
X_low = df_low[["Year", "FDI (%GDP)", "ODA Received", "Labor Force (%Population)", "Population", "Life Expectancy (Years)", "Trade (%GDP)", "Inflation", "Transparency_Accountability_Corruption_PublicSector_Rating", "Debt Policy Rating"]]
X_low = sm.add_constant(X_low)
y_low = df_low['GDP per capita']
model_low = sm.OLS(y_low,X_low).fit()

model_low.summary()

#really good model
#small coef for oda
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1749: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1749: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1671: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         GDP per capita   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 24 Feb 2022   Prob (F-statistic):                nan
# Time:                        16:38:00   Log-Likelihood:                 124.73
# No. Observations:                  10   AIC:                            -229.5
# Df Residuals:                       0   BIC:                            -226.4
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          0.1161        inf          0        nan         nan         nan
# Year                                                          52.3327        inf          0        nan         nan         nan
# FDI (%GDP)                                                   -57.5065        inf         -0        nan         nan         nan
# ODA Received                                                3.173e-08        inf          0        nan         nan         nan
# Labor Force (%Population)                                   -707.9930        inf         -0        nan         nan         nan
# Population                                                  5.751e-06        inf          0        nan         nan         nan
# Life Expectancy (Years)                                     -900.8930        inf         -0        nan         nan         nan
# Trade (%GDP)                                                 -19.6052        inf         -0        nan         nan         nan
# Inflation                                                    -25.0320        inf         -0        nan         nan         nan
# Transparency_Accountability_Corruption_PublicSector_Rating  -755.1875        inf         -0        nan         nan         nan
# Debt Policy Rating                                          -443.4348        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                        2.592   Durbin-Watson:                   1.011
# Prob(Omnibus):                  0.274   Jarque-Bera (JB):                1.077
# Skew:                          -0.372   Prob(JB):                        0.584
# Kurtosis:                       1.575   Cond. No.                     5.02e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 5.02e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
np.sqrt(mean_squared_error(y_low, model_low.predict(X_low)))
#our model is wrong by 7 dollars
# Out:
# 9.264882702187898e-07

# %%
#Lets see the regression with ODA only

X_ODA_low = df_low[["Year", "ODA Received"]]
X_ODA_low = sm.add_constant(X_ODA_low)
y_ODA_low = df_low['GDP per capita']
model_ODA_low = sm.OLS(y_ODA_low,X_ODA_low).fit()

model_ODA_low.summary()

#model is ok
#small coef for oda
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         GDP per capita   R-squared:                       0.581
# Model:                            OLS   Adj. R-squared:                  0.461
# Method:                 Least Squares   F-statistic:                     4.851
# Date:                Thu, 24 Feb 2022   Prob (F-statistic):             0.0477
# Time:                        16:38:00   Log-Likelihood:                -58.609
# No. Observations:                  10   AIC:                             123.2
# Df Residuals:                       7   BIC:                             124.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1.443e+05   5.81e+04      2.482      0.042    6828.588    2.82e+05
# Year           -71.6725     29.103     -2.463      0.043    -140.490      -2.855
# ODA Received  2.036e-08   1.32e-08      1.541      0.167   -1.09e-08    5.16e-08
# ==============================================================================
# Omnibus:                        1.539   Durbin-Watson:                   1.758
# Prob(Omnibus):                  0.463   Jarque-Bera (JB):                0.538
# Skew:                           0.565   Prob(JB):                        0.764
# Kurtosis:                       2.879   Cond. No.                     7.21e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.21e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
###ANALYSIS FOR Lower middle income

# %%
df_merge[df_merge["Country Name"]=="Lower middle income"].describe()
# Out:
#              Year  ODA Received  Labor Force (%Population)  \
# count    10.00000  1.000000e+01                  10.000000
# mean   2014.50000  4.485065e+10                  59.087671
# std       3.02765  4.082683e+09                   0.696918
# min    2010.00000  3.914048e+10                  58.432277
# 25%    2012.25000  4.235392e+10                  58.520868
# 50%    2014.50000  4.428579e+10                  58.852280
# 75%    2016.75000  4.660058e+10                  59.449176
# max    2019.00000  5.302362e+10                  60.406194
#
#        Debt Policy Rating    Population  Life Expectancy (Years)  \
# count           10.000000  1.000000e+01                10.000000
# mean             3.514610  3.081477e+09                67.866874
# std              0.077809  1.368447e+08                 0.916117
# min              3.384615  2.878875e+09                66.372159
# 25%              3.450658  2.979480e+09                67.223833
# 50%              3.554152  3.080909e+09                67.960777
# 75%              3.576290  3.183144e+09                68.577483
# max              3.585366  3.285417e+09                69.088492
#
#        Trade (%GDP)  Inflation  FDI (%GDP)  GDP per capita  \
# count     10.000000  10.000000   10.000000       10.000000
# mean      53.661379   4.487863    1.897563     2130.925875
# std        4.021169   1.002541    0.123398      151.977942
# min       47.336234   3.319254    1.725899     1806.542548
# 25%       50.652477   3.691041    1.818935     2085.497506
# 50%       54.430721   4.386205    1.896964     2122.424843
# 75%       55.939638   5.162040    1.936585     2239.932133
# max       59.655201   6.332795    2.168228     2354.578725
#
#        Transparency_Accountability_Corruption_PublicSector_Rating
# count                                          10.000000
# mean                                            2.948599
# std                                             0.037187
# min                                             2.865854
# 25%                                             2.937042
# 50%                                             2.947368
# 75%                                             2.976045
# max                                             2.988372

# %%
df_merge[df_merge["Country Name"]=="Lower middle income"].corr()
# Out:
#                                                         Year  ODA Received  \
# Year                                                1.000000      0.235140
# ODA Received                                        0.235140      1.000000
# Labor Force (%Population)                          -0.936761     -0.378705
# Debt Policy Rating                                 -0.866666      0.120203
# Population                                          0.999993      0.232802
# Life Expectancy (Years)                             0.995327      0.284009
# Trade (%GDP)                                       -0.641092     -0.122320
# Inflation                                          -0.826215      0.003324
# FDI (%GDP)                                          0.031930     -0.098707
# GDP per capita                                      0.901580      0.414126
# Transparency_Accountability_Corruption_PublicSe...  0.118180      0.706819
#
#                                                     Labor Force (%Population)  \
# Year                                                                -0.936761
# ODA Received                                                        -0.378705
# Labor Force (%Population)                                            1.000000
# Debt Policy Rating                                                   0.658225
# Population                                                          -0.935546
# Life Expectancy (Years)                                             -0.965772
# Trade (%GDP)                                                         0.709259
# Inflation                                                            0.777231
# FDI (%GDP)                                                           0.008631
# GDP per capita                                                      -0.869330
# Transparency_Accountability_Corruption_PublicSe...                  -0.382592
#
#                                                     Debt Policy Rating  \
# Year                                                         -0.866666
# ODA Received                                                  0.120203
# Labor Force (%Population)                                     0.658225
# Debt Policy Rating                                            1.000000
# Population                                                   -0.868408
# Life Expectancy (Years)                                      -0.819279
# Trade (%GDP)                                                  0.424345
# Inflation                                                     0.737439
# FDI (%GDP)                                                   -0.001504
# GDP per capita                                               -0.734379
# Transparency_Accountability_Corruption_PublicSe...            0.319092
#
#                                                     Population  \
# Year                                                  0.999993
# ODA Received                                          0.232802
# Labor Force (%Population)                            -0.935546
# Debt Policy Rating                                   -0.868408
# Population                                            1.000000
# Life Expectancy (Years)                               0.994981
# Trade (%GDP)                                         -0.640199
# Inflation                                            -0.826424
# FDI (%GDP)                                            0.032003
# GDP per capita                                        0.901101
# Transparency_Accountability_Corruption_PublicSe...    0.114946
#
#                                                     Life Expectancy (Years)  \
# Year                                                               0.995327
# ODA Received                                                       0.284009
# Labor Force (%Population)                                         -0.965772
# Debt Policy Rating                                                -0.819279
# Population                                                         0.994981
# Life Expectancy (Years)                                            1.000000
# Trade (%GDP)                                                      -0.666645
# Inflation                                                         -0.818686
# FDI (%GDP)                                                         0.029794
# GDP per capita                                                     0.906827
# Transparency_Accountability_Corruption_PublicSe...                 0.197801
#
#                                                     Trade (%GDP)  Inflation  \
# Year                                                   -0.641092  -0.826215
# ODA Received                                           -0.122320   0.003324
# Labor Force (%Population)                               0.709259   0.777231
# Debt Policy Rating                                      0.424345   0.737439
# Population                                             -0.640199  -0.826424
# Life Expectancy (Years)                                -0.666645  -0.818686
# Trade (%GDP)                                            1.000000   0.871759
# Inflation                                               0.871759   1.000000
# FDI (%GDP)                                             -0.123435  -0.007890
# GDP per capita                                         -0.368422  -0.552789
# Transparency_Accountability_Corruption_PublicSe...     -0.117316   0.099441
#
#                                                     FDI (%GDP)  \
# Year                                                  0.031930
# ODA Received                                         -0.098707
# Labor Force (%Population)                             0.008631
# Debt Policy Rating                                   -0.001504
# Population                                            0.032003
# Life Expectancy (Years)                               0.029794
# Trade (%GDP)                                         -0.123435
# Inflation                                            -0.007890
# FDI (%GDP)                                            1.000000
# GDP per capita                                       -0.049633
# Transparency_Accountability_Corruption_PublicSe...    0.108217
#
#                                                     GDP per capita  \
# Year                                                      0.901580
# ODA Received                                              0.414126
# Labor Force (%Population)                                -0.869330
# Debt Policy Rating                                       -0.734379
# Population                                                0.901101
# Life Expectancy (Years)                                   0.906827
# Trade (%GDP)                                             -0.368422
# Inflation                                                -0.552789
# FDI (%GDP)                                               -0.049633
# GDP per capita                                            1.000000
# Transparency_Accountability_Corruption_PublicSe...        0.348443
#
#                                                     Transparency_Accountability_Corruption_PublicSector_Rating
# Year                                                                                         0.118180
# ODA Received                                                                                 0.706819
# Labor Force (%Population)                                                                   -0.382592
# Debt Policy Rating                                                                           0.319092
# Population                                                                                   0.114946
# Life Expectancy (Years)                                                                      0.197801
# Trade (%GDP)                                                                                -0.117316
# Inflation                                                                                    0.099441
# FDI (%GDP)                                                                                   0.108217
# GDP per capita                                                                               0.348443
# Transparency_Accountability_Corruption_PublicSe...                                           1.000000

# %%
##Observations:
##1) GDP is strongly corr with variables, except ODA (not that much, but its positive), trade (not that much but it´s 
##negative which means that trade is not a good thing for those countries, while ODA is), fdi(low and negative), liability (not that much and positive)
## 2) ODA is not strongly related with anything except liability (positive)

# %%
df_lowermiddle=df_merge[df_merge["Country Name"]=="Lower middle income"]
df_lowermiddle.head(2)
# Out:
#           Country Name  Year  ODA Received  Labor Force (%Population)  \
# 4  Lower middle income  2010  3.914048e+10                  60.406194
# 9  Lower middle income  2011  4.117182e+10                  60.028412
#
#    Debt Policy Rating    Population  Life Expectancy (Years)  Trade (%GDP)  \
# 4            3.560976  2.878875e+09                66.372159     55.583573
# 9            3.559524  2.923660e+09                66.766305     59.655201
#
#    Inflation  FDI (%GDP)  GDP per capita  \
# 4   4.827342    1.889465     1806.542548
# 9   6.332795    1.982994     2030.275835
#
#    Transparency_Accountability_Corruption_PublicSector_Rating
# 4                                           2.865854
# 9                                           2.940476

# %%
X_lowermiddle = df_lowermiddle[["Year", "FDI (%GDP)", "ODA Received", "Labor Force (%Population)", "Life Expectancy (Years)", "Trade (%GDP)", "Inflation", "Transparency_Accountability_Corruption_PublicSector_Rating", "Debt Policy Rating"]]
X_lowermiddle = sm.add_constant(X_lowermiddle)
y_lowermiddle = df_lowermiddle['GDP per capita']
model_lowermiddle = sm.OLS(y_lowermiddle,X_lowermiddle).fit()
#model_lowermiddle
model_lowermiddle.summary()

#really good model
#small coef for oda
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         GDP per capita   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     4.810
# Date:                Thu, 24 Feb 2022   Prob (F-statistic):              0.339
# Time:                        16:38:00   Log-Likelihood:                -45.521
# No. Observations:                  10   AIC:                             109.0
# Df Residuals:                       1   BIC:                             111.8
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -0.4609      3.017     -0.153      0.903     -38.799      37.877
# Year                                                         -22.0138     38.156     -0.577      0.667    -506.830     462.802
# FDI (%GDP)                                                  -196.4545    286.025     -0.687      0.617   -3830.743    3437.834
# ODA Received                                               -2.159e-09   1.19e-08     -0.181      0.886   -1.54e-07    1.49e-07
# Labor Force (%Population)                                    244.3076    498.470      0.490      0.710   -6089.354    6577.970
# Life Expectancy (Years)                                      414.2640    613.136      0.676      0.622   -7376.372    8204.900
# Trade (%GDP)                                                   3.2668     18.917      0.173      0.891    -237.099     243.633
# Inflation                                                     39.7445     95.470      0.416      0.749   -1173.321    1252.810
# Transparency_Accountability_Corruption_PublicSector_Rating  1759.3376   1766.427      0.996      0.501   -2.07e+04    2.42e+04
# Debt Policy Rating                                          -325.4451   2011.451     -0.162      0.898   -2.59e+04    2.52e+04
# ==============================================================================
# Omnibus:                        1.098   Durbin-Watson:                   3.437
# Prob(Omnibus):                  0.578   Jarque-Bera (JB):                0.791
# Skew:                           0.403   Prob(JB):                        0.673
# Kurtosis:                       1.882   Cond. No.                     1.19e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.19e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
np.sqrt(mean_squared_error(y_lowermiddle, model_lowermiddle.predict(X_lowermiddle)))
#our model is wrong by 15 dollars
# Out:
# 22.946219312508212

# %%
#lets see the regression with ODA only

X_ODA_lowermiddle = df_lowermiddle[["Year", "ODA Received"]]
X_ODA_lowermiddle = sm.add_constant(X_ODA_lowermiddle)
y_ODA_lowermiddle = df_lowermiddle['GDP per capita']
model_ODA_lowermiddle = sm.OLS(y_ODA_lowermiddle, X_ODA_lowermiddle).fit()

model_ODA_lowermiddle.summary()

#really good model
#small coef for oda
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         GDP per capita   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     20.82
# Date:                Thu, 24 Feb 2022   Prob (F-statistic):            0.00113
# Time:                        16:38:00   Log-Likelihood:                -54.207
# No. Observations:                  10   AIC:                             114.4
# Df Residuals:                       7   BIC:                             115.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -8.431e+04   1.49e+04     -5.673      0.001   -1.19e+05   -4.92e+04
# Year            42.7309      7.405      5.771      0.001      25.221      60.241
# ODA Received  7.965e-09   5.49e-09      1.450      0.190   -5.02e-09    2.09e-08
# ==============================================================================
# Omnibus:                        0.258   Durbin-Watson:                   1.838
# Prob(Omnibus):                  0.879   Jarque-Bera (JB):                0.404
# Skew:                           0.005   Prob(JB):                        0.817
# Kurtosis:                       2.015   Cond. No.                     3.24e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.24e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
##Predicting for Lower Middle Income Countries & Least Developed Countries (positive relation between GDP and ODA)
#Questions: How will they be if we increase the ODA for 0.7% of the GDP of the OECD/DAC donor countries in 2022? Will they change
#their income classification?

# %%
##First, we need to predict the GDP of the DAC donor countries for 2022
##Second, we need to predict our indep variable values for 2022
##Third, using our regression models for Lower Middle Income Countries & Least Developed Countries, we can see how their GDP will be affected

# %%
###Predicting the DAC countries GDP

GDP_DonorCountries = pd.read_excel("GDP DAC.xls")


list_DonorCountries=["Australia", "Austria", "Belgium", "Canada", "Czech Republic", "Denmark", "European Union", "Finland", "France",
              "Germany", "Greece", "Hungary", "Iceland", "Ireland", "Italy", "Japan", "Korea", "Luxembourg", "The Netherland",
              "New Zealand", "Norway", "Poland", "Portugal", "Slovak Republic", "Slovenia", "Spain", "Sweden", "Switzerland",
              "United Kingdom", "United States"]


condition=GDP_DonorCountries["Country Name"].isin(list_DonorCountries)
    
GDP_DonorCountries=GDP_DonorCountries[condition].copy()

GDP_DonorCountries.head()
# Out:
#    Country Name          1960          1961          1962          1963  \
# 13    Australia  1.860679e+10  1.968306e+10  1.992272e+10  2.153993e+10
# 14      Austria  6.592694e+09  7.311750e+09  7.756110e+09  8.374175e+09
# 17      Belgium  1.165872e+10  1.240015e+10  1.326402e+10  1.426002e+10
# 35       Canada  4.046172e+10  4.093495e+10  4.222745e+10  4.502999e+10
# 37  Switzerland  9.522747e+09  1.071271e+10  1.187998e+10  1.306364e+10
#
#             1964          1965          1966          1967          1968  ...  \
# 13  2.380110e+10  2.597715e+10  2.730989e+10  3.044462e+10  3.271699e+10  ...
# 14  9.169984e+09  9.994071e+09  1.088768e+10  1.157943e+10  1.244063e+10  ...
# 17  1.596011e+10  1.737146e+10  1.865188e+10  1.999204e+10  2.137635e+10  ...
# 35  4.937752e+10  5.451518e+10  6.108838e+10  6.566866e+10  7.182981e+10  ...
# 37  1.448056e+10  1.534674e+10  1.648006e+10  1.774001e+10  1.894273e+10  ...
#
#             2011          2012          2013          2014          2015  \
# 13  1.397908e+12  1.546509e+12  1.576335e+12  1.467505e+12  1.350534e+12
# 14  4.311203e+11  4.094252e+11  4.300687e+11  4.419961e+11  3.818176e+11
# 17  5.226455e+11  4.961813e+11  5.216427e+11  5.346781e+11  4.621497e+11
# 35  1.793327e+12  1.828366e+12  1.846597e+12  1.805750e+12  1.556509e+12
# 37  7.220382e+11  6.921097e+11  7.127481e+11  7.343966e+11  7.021496e+11
#
#             2016          2017          2018          2019          2020
# 13  1.206685e+12  1.326883e+12  1.428530e+12  1.391953e+12  1.327836e+12
# 14  3.955686e+11  4.162305e+11  4.549459e+11  4.450119e+11  4.332585e+11
# 17  4.757396e+11  5.015229e+11  5.430085e+11  5.352887e+11  5.218613e+11
# 35  1.527995e+12  1.649266e+12  1.725329e+12  1.742015e+12  1.645423e+12
# 37  6.956007e+11  7.044785e+11  7.355393e+11  7.317674e+11  7.522480e+11
#
# [5 rows x 62 columns]

# %%
GDP_DonorCountries_filter=pd.melt(GDP_DonorCountries, id_vars=['Country Name'])
GDP_DonorCountries_filter["variable"] = GDP_DonorCountries_filter["variable"].astype(int)
GDP_DonorCountries_2010_2019=GDP_DonorCountries_filter[(GDP_DonorCountries_filter["variable"]>=2010)&(GDP_DonorCountries_filter["variable"]<=2019)]
GDP_DonorCountries_2010_2019.rename(columns={"value":"GDP"}, inplace=True)
GDP_DonorCountries_2010_2019.rename(columns={"variable":"Year"}, inplace=True)
GDP_DonorCountries_2010_2019
# Out:
# /var/folders/j7/4yrzqvzn643dv0t5y434hfhw0000gn/T/ipykernel_16317/3022771968.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GDP_DonorCountries_2010_2019.rename(columns={"value":"GDP"}, inplace=True)
# /var/folders/j7/4yrzqvzn643dv0t5y434hfhw0000gn/T/ipykernel_16317/3022771968.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GDP_DonorCountries_2010_2019.rename(columns={"variable":"Year"}, inplace=True)
#          Country Name  Year           GDP
# 1400        Australia  2010  1.147589e+12
# 1401          Austria  2010  3.918927e+11
# 1402          Belgium  2010  4.809516e+11
# 1403           Canada  2010  1.617343e+12
# 1404      Switzerland  2010  6.034345e+11
# ...               ...   ...           ...
# 1675         Portugal  2019  2.399869e+11
# 1676  Slovak Republic  2019  1.052844e+11
# 1677         Slovenia  2019  5.417888e+10
# 1678           Sweden  2019  5.338795e+11
# 1679    United States  2019  2.143322e+13
#
# [280 rows x 3 columns]

# %%
GDP_DonorCountries_2010_2019_Total= GDP_DonorCountries_2010_2019.groupby("Year").agg({"GDP":"sum"})
GDP_DonorCountries_2010_2019_Total=GDP_DonorCountries_2010_2019_Total.reset_index()
GDP_DonorCountries_2010_2019_Total
# Out:
#    Year           GDP
# 0  2010  5.505114e+13
# 1  2011  5.918961e+13
# 2  2012  5.798015e+13
# 3  2013  5.893926e+13
# 4  2014  6.015744e+13
# 5  2015  5.575845e+13
# 6  2016  5.704504e+13
# 7  2017  5.965314e+13
# 8  2018  6.361485e+13
# 9  2019  6.389556e+13

# %%
GDP_DonorCountries_2010_2019_Total.dtypes
# Out:
# Year      int64
# GDP     float64
# dtype: object

# %%
GDP_DonorCountries_2010_2019_Total["Year"]=GDP_DonorCountries_2010_2019_Total["Year"].astype(str)
GDP_DonorCountries_2010_2019_Total.dtypes
# Out:
# Year     object
# GDP     float64
# dtype: object

# %%
GDP_DonorCountries_2010_2019_Total["GDP"]=GDP_DonorCountries_2010_2019_Total["GDP"].astype(float)

# %%
GDP_DonorCountries_2010_2019_Total.dtypes
# Out:
# Year     object
# GDP     float64
# dtype: object

# %%
GDP_DonorCountries_2010_2019_Total["Year"]=pd.to_datetime(GDP_DonorCountries_2010_2019_Total["Year"])
GDP_DonorCountries_2010_2019_Total.index=pd.DatetimeIndex(GDP_DonorCountries_2010_2019_Total["Year"]) 
display(GDP_DonorCountries_2010_2019_Total.head())
# Out:
#                  Year           GDP
# Year
# 2010-01-01 2010-01-01  5.505114e+13
# 2011-01-01 2011-01-01  5.918961e+13
# 2012-01-01 2012-01-01  5.798015e+13
# 2013-01-01 2013-01-01  5.893926e+13
# 2014-01-01 2014-01-01  6.015744e+13

# %%
##create a train and test set

train=GDP_DonorCountries_2010_2019_Total["GDP"]

##create a model

model=AutoReg(endog=train, lags=1)

##train
model_fit=model.fit()

##make prediction

predictions_GDP_DonorCountries=model_fit.predict(start=len(train), end=len(train)+2)
predictions_GDP_DonorCountries
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# 2020-01-01    6.491460e+13
# 2021-01-01    6.594989e+13
# 2022-01-01    6.700170e+13
# Freq: AS-JAN, dtype: float64

# %%
df_lowermiddle["Year"]=df_lowermiddle["Year"].astype(str)
df_lowermiddle.dtypes
df_lowermiddle["Year"]=pd.to_datetime(df_lowermiddle["Year"])
df_lowermiddle.index=pd.DatetimeIndex(df_lowermiddle["Year"]) 
display(df_lowermiddle.head())
# Out:
# /var/folders/j7/4yrzqvzn643dv0t5y434hfhw0000gn/T/ipykernel_16317/2236220685.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lowermiddle["Year"]=df_lowermiddle["Year"].astype(str)
# /var/folders/j7/4yrzqvzn643dv0t5y434hfhw0000gn/T/ipykernel_16317/2236220685.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lowermiddle["Year"]=pd.to_datetime(df_lowermiddle["Year"])
#                    Country Name       Year  ODA Received  \
# Year
# 2010-01-01  Lower middle income 2010-01-01  3.914048e+10
# 2011-01-01  Lower middle income 2011-01-01  4.117182e+10
# 2012-01-01  Lower middle income 2012-01-01  4.348410e+10
# 2013-01-01  Lower middle income 2013-01-01  5.302362e+10
# 2014-01-01  Lower middle income 2014-01-01  4.924119e+10
#
#             Labor Force (%Population)  Debt Policy Rating    Population  \
# Year
# 2010-01-01                  60.406194            3.560976  2.878875e+09
# 2011-01-01                  60.028412            3.559524  2.923660e+09
# 2012-01-01                  59.521931            3.583333  2.968244e+09
# 2013-01-01                  59.230913            3.581395  3.013187e+09
# 2014-01-01                  58.958290            3.585366  3.058249e+09
#
#             Life Expectancy (Years)  Trade (%GDP)  Inflation  FDI (%GDP)  \
# Year
# 2010-01-01                66.372159     55.583573   4.827342    1.889465
# 2011-01-01                66.766305     59.655201   6.332795    1.982994
# 2012-01-01                67.136205     58.273244   5.196186    1.804937
# 2013-01-01                67.486718     56.058326   5.316235    1.777123
# 2014-01-01                67.811507     53.836012   5.059601    1.919213
#
#             GDP per capita  \
# Year
# 2010-01-01     1806.542548
# 2011-01-01     2030.275835
# 2012-01-01     2098.934416
# 2013-01-01     2105.310154
# 2014-01-01     2157.087989
#
#             Transparency_Accountability_Corruption_PublicSector_Rating
# Year
# 2010-01-01                                           2.865854
# 2011-01-01                                           2.940476
# 2012-01-01                                           2.976190
# 2013-01-01                                           2.988372
# 2014-01-01                                           2.975610

# %%
#Function to predict the values I want

def predict(row):
    train_Recipients=row
    model=AutoReg(endog=train_Recipients, lags=1)
    model_fit=model.fit()
    predictions=model_fit.predict(start=len(train_Recipients), end=len(train_Recipients)+2)
    return predictions

# %%
###Predicting for Lower Middle Income Countries

# %%
predict(df_lowermiddle["Debt Policy Rating"])
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# 2020-01-01    3.344850
# 2021-01-01    3.299532
# 2022-01-01    3.247885
# Freq: AS-JAN, dtype: float64

# %%
predict(df_lowermiddle["Population"])
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# 2020-01-01    3.331147e+09
# 2021-01-01    3.376990e+09
# 2022-01-01    3.422945e+09
# Freq: AS-JAN, dtype: float64

# %%
predict(df_lowermiddle["Labor Force (%Population)"])
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# 2020-01-01    58.452138
# 2021-01-01    58.402171
# 2022-01-01    58.363638
# Freq: AS-JAN, dtype: float64

# %%
predict(df_lowermiddle["Life Expectancy (Years)"])
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# 2020-01-01    69.291825
# 2021-01-01    69.480407
# 2022-01-01    69.655306
# Freq: AS-JAN, dtype: float64

# %%
predict(df_lowermiddle["Trade (%GDP)"])
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# 2020-01-01    51.771654
# 2021-01-01    52.029671
# 2022-01-01    52.200413
# Freq: AS-JAN, dtype: float64

# %%
predict(df_lowermiddle["Inflation"])
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# 2020-01-01    3.513861
# 2021-01-01    3.654188
# 2022-01-01    3.755373
# Freq: AS-JAN, dtype: float64

# %%
predict(df_lowermiddle["FDI (%GDP)"])
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# 2020-01-01    1.882322
# 2021-01-01    1.901788
# 2022-01-01    1.895479
# Freq: AS-JAN, dtype: float64

# %%
predict(df_lowermiddle["Transparency_Accountability_Corruption_PublicSector_Rating"])
# Out:
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# /Users/barbaramuniz/opt/anaconda3/envs/ironh/lib/python3.10/site-packages/statsmodels/tsa/deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# 2020-01-01    2.953307
# 2021-01-01    2.958841
# 2022-01-01    2.960600
# Freq: AS-JAN, dtype: float64

# %%
df_lowermiddle["ODA Received"].tail()
# Out:
# Year
# 2015-01-01    4.508747e+10
# 2016-01-01    4.300172e+10
# 2017-01-01    4.512603e+10
# 2018-01-01    4.213798e+10
# 2019-01-01    4.709210e+10
# Name: ODA Received, dtype: float64

# %%
4.709210e+10
# Out:
# 47092100000.0

# %%
(6.700170e+13)*0.007
# Out:
# 469011900000.0

# %%
#Adding the results for 2022 in our regression model:
future_gdp_lowermiddle = pd.DataFrame([{"const": -37.5696, 'ODA Received': (6.700170e+13)*0.007, 'Life Expectancy (Years)': 69.655306, 'Labor Force (%Population)':58.363638 , 'Debt Policy Rating': 3.247885, 'Trade (%GDP)': 52.200413, 'Inflation': 3.755373, 'FDI (%GDP)': 1.895479, 'Transparency_Accountability_Corruption_PublicSector_Rating': 2.960600, "Year":2022}])
model_lowermiddle.predict(future_gdp_lowermiddle)
# Out:
# 0   -1.032474e+13
# dtype: float64

# %%
#model_lowermiddle

# %%
###Predicting for Least Developed Countries

# %%
#predict(df_least["Labor Force (%Population)"])

# %%
#predict(df_least["Debt Policy Rating"])

# %%
#predict(df_least["Population"])

# %%
#predict(df_least["Life Expectancy (Years)"])

# %%
#predict(df_least["Trade (%GDP)"])

# %%
#predict(df_least["Inflation"])

# %%
#predict(df_least["FDI (%GDP)"])

# %%
#predict(df_least["Transparency_Accountability_Corruption_PublicSector_Rating"])

# %%
#Adding the results to our regression model:
